# %%
from Prob_Vector import ProbabilityVector
from Prob_Matrix import ProbabilityMatrix

# %%
a1 = ProbabilityVector({'rain':0.7, 'sun': 0.3})
a2 = ProbabilityVector({'rain': 0.6, 'sun':0.4})
A = ProbabilityMatrix({'hot':a1, 'cold':a2})

# %%
print(A)
# Out:
# PM (2, 2) states ['cold', 'hot']: -> obs: ['rain', 'sun'].

# %%
print(A.df)
# Out:
#       rain  sun
# cold   0.6  0.4
# hot    0.7  0.3

# %%
b1 = ProbabilityVector({'0S': 0.1, '1M': 0.4, '2L':0.5})
b2 = ProbabilityVector({'0S': 0.7, '1M': 0.2, '2L':0.1})
B =  ProbabilityMatrix({'0H': b1, '1C': b2})

# %%
print(B)
# Out:
# PM (2, 3) states ['0H', '1C']: -> obs: ['0S', '1M', '2L'].

# %%
P = ProbabilityMatrix.initialize(list('abcd'), list('xyz'))
print('Dot Product:', a1 @ A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 P = ProbabilityMatrix.initialize(list('abcd'), list('xyz'))
#       2 print('Dot Product:', a1 @ A)
#
# File ~/Documents/HMM_FFT/HMM/Python/Fundamentals_HMM/Prob_Matrix.py:24, in ProbabilityMatrix.initialize(cls, states, observables)
#      22 rand /= rand.sum(axis=1).reshape(-1,1)
#      23 aggr = [dict(zip(observables, rand[i,:])) for i in range(len(states))]
# ---> 24 pvec = [ProbabilityVector(x) for x in aggr]
#      25 return cls(dict(zip(states, pvec)))
#
# File ~/Documents/HMM_FFT/HMM/Python/Fundamentals_HMM/Prob_Matrix.py:24, in <listcomp>(.0)
#      22 rand /= rand.sum(axis=1).reshape(-1,1)
#      23 aggr = [dict(zip(observables, rand[i,:])) for i in range(len(states))]
# ---> 24 pvec = [ProbabilityVector(x) for x in aggr]
#      25 return cls(dict(zip(states, pvec)))
#
# NameError: name 'ProbabilityVector' is not defined

# %%
# Out:
# Score for ['1S', '2M', '3L', '2M', '1S'] is 0.000115
# Score for ['1S', '2M', '3L', '2M', '1S'] is 0.000000
